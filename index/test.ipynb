# %%
from retrieval import Retrieval
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from retrieval import Retrieval
#
# File c:\Users\davin\OneDrive\Desktop\ML (practice)\BOM-RAG\index\retrieval.py:2
#       1 from scripture_storage import ScriptureStorage, Verse
# ----> 2 from scripture_embedding import ScriptureEmbedder
#       3 from scripture_index import ScriptureIndex
#       5 class Retrieval:
#
# ImportError: cannot import name 'ScriptureEmbedder' from 'scripture_embedding' (c:\Users\davin\OneDrive\Desktop\ML (practice)\BOM-RAG\index\scripture_embedding.py)
